# %% [markdown]
# <a href="https://colab.research.google.com/github/codernikita/Github-workshop/blob/main/miniproject_marks_adding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/Mini Project - Marks Adding.csv')

# %%
print(data)
# Out:
#        Roll Num  Marks
# 0     102003542      1
# 1     102003640      1
# 2     102003725      1
# 3     102003307      1
# 4     102003458      1
# ...         ...    ...
# 1831  102003755      1
# 1832  102017147      1
# 1833  102017152      1
# 1834  102003451      1
# 1835  102003549      1
#
# [1836 rows x 2 columns]

# %%
data.sort_values(by=['Roll Num'])
# Out:
#        Roll Num  Marks
# 214   102003001      1
# 1219  102003001      1
# 953   102003001      0
# 939   102003001      1
# 1114  102003002      1
# ...         ...    ...
# 531   102197021      1
# 621   102197021      1
# 1630  102197021      1
# 1385  102197021      1
# 752   102197021      1
#
# [1836 rows x 2 columns]

# %%
roll_number_sum = data.groupby('Roll Num')['Marks'].sum()
print(roll_number_sum)
# Out:
# Roll Num
# 102003001    3
# 102003002    5
# 102003017    5
# 102003018    5
# 102003029    5
#             ..
# 102196010    4
# 102197016    5
# 102197018    4
# 102197019    5
# 102197021    5
# Name: Marks, Length: 400, dtype: int64
